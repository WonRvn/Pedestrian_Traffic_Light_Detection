# %% [markdown]
# ## **Inference with Custom Model**

# %%
# %pip install openvino-dev
# %pip install pyttsx3 --upgrade

# %%
from ultralytics import YOLO

# Define the path to the model weights and the source directory of images
model_weights = 'runs/detect/train/weights/best.pt'
source_images = "C:/Users/wonha/OneDrive/Desktop/Wonha/UNIV/Personal_Projects/Pedestrain_Traffic_Light/Pedestrian Lights.v1i.yolov8/test/images"

# Create a YOLO object with the specified model weights and set the confidence threshold
yolo = YOLO(model_weights)

# Run detection on the source images
results = yolo.predict(source=source_images)

# %%
# %pip install opencv-python-headless
# %pip install lap
# %pip install pafy
# %pip install youtube-dl

# %%
import pyttsx3
engine = pyttsx3.init()
engine.say("테스트 메시지")
engine.runAndWait()

# %%
import cv2
from ultralytics import YOLO
import pyttsx3

# Load your trained model
model = YOLO('runs2/detect/train/weights/best.pt')

# Initialize the text-to-speech engine
engine = pyttsx3.init()

# Open a handle to the default webcam
cap = cv2.VideoCapture(0)

def speak(text):
    print(f"Speaking: {text}")
    engine.say(text)
    engine.runAndWait()

# Ensure the webcam opened correctly
if not cap.isOpened():
    raise IOError("Cannot open webcam")

ret = True

while ret:
    ret, frame = cap.read()
    if not ret:
        print("Failed to grab frame")
        break

    # Simulate zoom by cropping and resizing
    height, width = frame.shape[:2]
    zoom_factor = 1

    # Calculate the size of the region of interest
    centerX, centerY = width // 2, height // 2
    roiWidth, roiHeight = int(width // zoom_factor), int(height // zoom_factor)
    minX, maxX = int(centerX - roiWidth // 2), int(centerX + roiWidth // 2)
    minY, maxY = int(centerY - roiHeight // 2), int(centerY + roiHeight // 2)

    # Crop and resize (zoom in)
    cropped_frame = frame[minY:maxY, minX:maxX]
    resized_frame = cv2.resize(cropped_frame, (width, height), interpolation=cv2.INTER_LINEAR)

    ## Apply Bilateral Filter for advanced image smoothing
    smoothed_frame = cv2.bilateralFilter(resized_frame, 9, 50, 50)

    # Perform detection on the smoothed and zoomed frame
    results = model.track(smoothed_frame, persist=True, conf=0.6)

    # Convert the result tensor to a list
    detections = results[0]

    # Display the frame with detections
    cv2.imshow('Real-time Traffic Light Detection', detections.plot())

    # Speak the traffic light color
    if detections.boxes.is_track == True:
        label = detections.boxes.cls  # The label is a tensor
        label_int = int(label.item())  # Convert tensor to integer
        print("Detected label:", label_int)  # Debugging line
        if label_int == 0:  # green
            speak("초록불 탐지")
        elif label_int == 1:  # red
            speak("빨간불 탐지")

    # Break the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the VideoCapture object and close all windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 184.6ms
# Speed: 1.8ms preprocess, 184.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 153.7ms
# Speed: 0.0ms preprocess, 153.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 186.1ms
# Speed: 0.0ms preprocess, 186.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 167.7ms
# Speed: 1.1ms preprocess, 167.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 156.4ms
# Speed: 15.3ms preprocess, 156.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 164.8ms
# Speed: 0.0ms preprocess, 164.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 159.9ms
# Speed: 15.6ms preprocess, 159.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# ...
