# %% [markdown]
# ## **Inference with Custom Model**

# %%
# %pip install openvino-dev
# %pip install pyttsx3 --upgrade

# %%
from ultralytics import YOLO

# Define the path to the model weights and the source directory of images
model_weights = 'runs/detect/train/weights/best.pt'
source_images = "C:/Users/wonha/OneDrive/Desktop/Wonha/UNIV/Personal_Projects/Pedestrain_Traffic_Light/Pedestrian Lights.v1i.yolov8/test/images"

# Create a YOLO object with the specified model weights and set the confidence threshold
yolo = YOLO(model_weights)

# Run detection on the source images
results = yolo.predict(source=source_images)

# %%
# %pip install opencv-python-headless
# %pip install lap
# %pip install pafy
# %pip install youtube-dl

# %%
import pyttsx3
engine = pyttsx3.init()
engine.say("테스트 메시지")
engine.runAndWait()

# %%
import cv2
from ultralytics import YOLO
import pyttsx3

# Load your trained model
model = YOLO('runs/detect/train/weights/best.pt')

# Initialize the text-to-speech engine
engine = pyttsx3.init()

# Open a handle to the default webcam
cap = cv2.VideoCapture(0)

def speak(text):
    print(f"Speaking: {text}")
    engine.say(text)
    engine.runAndWait()

# Ensure the webcam opened correctly
if not cap.isOpened():
    raise IOError("Cannot open webcam")

ret = True

while ret:
    ret, frame = cap.read()
    if not ret:
        print("Failed to grab frame")
        break

    # Perform detection
    results = model.track(frame, persist=True, conf=0.733)

    # Convert the result tensor to a list
    detections = results[0]

    print(detections.boxes)

    # Display the frame with detections
    cv2.imshow('Real-time Traffic Light Detection', detections.plot())

    # Speak the traffic light color
    if detections.boxes.is_track == True:
        label = detections.boxes.cls # The label is a tensor
        label_int = int(label.item())  # Convert tensor to integer
        print("Detected label:", label_int)  # Debugging line
        if label_int == 0: # green
            speak("초록불 탐지")
        elif label_int == 1: # red
            speak("빨간불 탐지")

    # Break the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the VideoCapture object and close all windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 112.7ms
# Speed: 0.0ms preprocess, 112.7ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 104.8ms
# Speed: 0.0ms preprocess, 104.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 104.5ms
# Speed: 0.0ms preprocess, 104.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 96.2ms
# Speed: 0.0ms preprocess, 96.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 104.7ms
# Speed: 0.0ms preprocess, 104.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 104.5ms
# Speed: 0.0ms preprocess, 104.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 96.3ms
# Speed: 0.0ms preprocess, 96.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 99.7ms
# Speed: 0.0ms preprocess, 99.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 104.9ms
# Speed: 0.0ms preprocess, 104.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 105.6ms
# Speed: 0.0ms preprocess, 105.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 104.1ms
# Speed: 0.0ms preprocess, 104.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 96.6ms
# Speed: 0.0ms preprocess, 96.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 96.9ms
# Speed: 0.0ms preprocess, 96.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 97.0ms
# Speed: 0.0ms preprocess, 97.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 96.6ms
# Speed: 0.0ms preprocess, 96.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 111.5ms
# Speed: 0.0ms preprocess, 111.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 102.2ms
# Speed: 3.0ms preprocess, 102.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 105.5ms
# Speed: 0.0ms preprocess, 105.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 104.7ms
# Speed: 0.0ms preprocess, 104.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 99.2ms
# Speed: 0.0ms preprocess, 99.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 88.7ms
# Speed: 0.0ms preprocess, 88.7ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 105.1ms
# Speed: 0.0ms preprocess, 105.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 104.1ms
# Speed: 0.0ms preprocess, 104.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 126.8ms
# Speed: 0.0ms preprocess, 126.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 105.1ms
# Speed: 0.0ms preprocess, 105.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 96.9ms
# Speed: 0.0ms preprocess, 96.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 97.2ms
# Speed: 0.0ms preprocess, 97.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 100.4ms
# Speed: 4.5ms preprocess, 100.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 93.3ms
# Speed: 3.3ms preprocess, 93.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 95.6ms
# Speed: 1.6ms preprocess, 95.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 96.9ms
# Speed: 0.0ms preprocess, 96.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 105.1ms
# Speed: 0.0ms preprocess, 105.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 105.2ms
# Speed: 0.0ms preprocess, 105.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 96.1ms
# Speed: 0.0ms preprocess, 96.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 108.1ms
# Speed: 0.0ms preprocess, 108.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 100.8ms
# Speed: 1.6ms preprocess, 100.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 96.2ms
# Speed: 0.0ms preprocess, 96.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 97.8ms
# Speed: 0.0ms preprocess, 97.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 98.0ms
# Speed: 0.0ms preprocess, 98.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 100.0ms
# Speed: 0.0ms preprocess, 100.0ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 1 green, 96.9ms
# Speed: 0.0ms preprocess, 96.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.7989])
# data: tensor([[290.3068, 314.2924, 344.4637, 384.1659,   1.0000,   0.7989,   0.0000]])
# id: tensor([1.])
# is_track: True
# orig_shape: (480, 640)
# shape: torch.Size([1, 7])
# xywh: tensor([[317.3853, 349.2292,  54.1569,  69.8735]])
# xywhn: tensor([[0.4959, 0.7276, 0.0846, 0.1456]])
# xyxy: tensor([[290.3068, 314.2924, 344.4637, 384.1659]])
# xyxyn: tensor([[0.4536, 0.6548, 0.5382, 0.8003]])
# Detected label: 0
# Speaking: 초록불 탐지
#
# 0: 480x640 (no detections), 119.8ms
# Speed: 1.8ms preprocess, 119.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 118.4ms
# Speed: 2.1ms preprocess, 118.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 106.1ms
# Speed: 0.0ms preprocess, 106.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 133.0ms
# Speed: 3.9ms preprocess, 133.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 101.6ms
# Speed: 0.0ms preprocess, 101.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 104.8ms
# Speed: 0.0ms preprocess, 104.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 100.3ms
# Speed: 1.5ms preprocess, 100.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 96.4ms
# Speed: 0.0ms preprocess, 96.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 104.7ms
# Speed: 0.0ms preprocess, 104.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 105.3ms
# Speed: 0.0ms preprocess, 105.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 103.2ms
# Speed: 0.0ms preprocess, 103.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 108.0ms
# Speed: 0.0ms preprocess, 108.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 133.8ms
# Speed: 2.8ms preprocess, 133.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 105.1ms
# Speed: 0.0ms preprocess, 105.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 105.0ms
# Speed: 0.0ms preprocess, 105.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 105.2ms
# Speed: 0.0ms preprocess, 105.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 113.3ms
# Speed: 0.0ms preprocess, 113.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 112.2ms
# Speed: 0.0ms preprocess, 112.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 120.6ms
# Speed: 0.0ms preprocess, 120.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 120.9ms
# Speed: 0.0ms preprocess, 120.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 185.4ms
# Speed: 8.0ms preprocess, 185.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 144.1ms
# Speed: 0.0ms preprocess, 144.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 141.3ms
# Speed: 0.0ms preprocess, 141.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 129.1ms
# Speed: 0.0ms preprocess, 129.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 135.3ms
# Speed: 5.0ms preprocess, 135.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 105.7ms
# Speed: 0.0ms preprocess, 105.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 115.6ms
# Speed: 0.0ms preprocess, 115.6ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 134.1ms
# Speed: 0.0ms preprocess, 134.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 154.8ms
# Speed: 2.2ms preprocess, 154.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 135.0ms
# Speed: 2.4ms preprocess, 135.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 128.3ms
# Speed: 0.0ms preprocess, 128.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 137.3ms
# Speed: 0.0ms preprocess, 137.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 129.1ms
# Speed: 0.0ms preprocess, 129.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 115.7ms
# Speed: 0.0ms preprocess, 115.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 107.1ms
# Speed: 0.0ms preprocess, 107.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 162.6ms
# Speed: 0.0ms preprocess, 162.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 149.4ms
# Speed: 3.6ms preprocess, 149.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 1 green, 153.0ms
# Speed: 0.0ms preprocess, 153.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.8044])
# data: tensor([[255.6018, 274.5748, 323.5653, 346.3509,   1.0000,   0.8044,   0.0000]])
# id: tensor([1.])
# is_track: True
# orig_shape: (480, 640)
# shape: torch.Size([1, 7])
# xywh: tensor([[289.5836, 310.4628,  67.9635,  71.7761]])
# xywhn: tensor([[0.4525, 0.6468, 0.1062, 0.1495]])
# xyxy: tensor([[255.6018, 274.5748, 323.5653, 346.3509]])
# xyxyn: tensor([[0.3994, 0.5720, 0.5056, 0.7216]])
# Detected label: 0
# Speaking: 초록불 탐지
#
# 0: 480x640 (no detections), 156.6ms
# Speed: 3.9ms preprocess, 156.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 198.7ms
# Speed: 6.3ms preprocess, 198.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 171.2ms
# Speed: 0.0ms preprocess, 171.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 165.9ms
# Speed: 4.6ms preprocess, 165.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 180.5ms
# Speed: 0.0ms preprocess, 180.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 159.2ms
# Speed: 2.3ms preprocess, 159.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 169.3ms
# Speed: 2.7ms preprocess, 169.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 157.3ms
# Speed: 0.0ms preprocess, 157.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 162.0ms
# Speed: 0.0ms preprocess, 162.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 138.7ms
# Speed: 0.0ms preprocess, 138.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 105.9ms
# Speed: 0.0ms preprocess, 105.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 115.0ms
# Speed: 0.0ms preprocess, 115.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 105.9ms
# Speed: 0.0ms preprocess, 105.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 161.6ms
# Speed: 0.0ms preprocess, 161.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 104.0ms
# Speed: 2.6ms preprocess, 104.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 106.3ms
# Speed: 0.0ms preprocess, 106.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 102.2ms
# Speed: 2.9ms preprocess, 102.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 1 red, 105.9ms
# Speed: 0.0ms preprocess, 105.9ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([1.])
# conf: tensor([0.7558])
# data: tensor([[304.2230, 253.8968, 370.6959, 328.6633,   0.7558,   1.0000]])
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([1, 6])
# xywh: tensor([[337.4595, 291.2801,  66.4729,  74.7665]])
# xywhn: tensor([[0.5273, 0.6068, 0.1039, 0.1558]])
# xyxy: tensor([[304.2230, 253.8968, 370.6959, 328.6633]])
# xyxyn: tensor([[0.4753, 0.5290, 0.5792, 0.6847]])
#
# 0: 480x640 1 red, 105.1ms
# Speed: 0.0ms preprocess, 105.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([1.])
# conf: tensor([0.8645])
# data: tensor([[287.5254, 229.0192, 348.2635, 295.5726,   0.8645,   1.0000]])
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([1, 6])
# xywh: tensor([[317.8945, 262.2959,  60.7382,  66.5533]])
# xywhn: tensor([[0.4967, 0.5464, 0.0949, 0.1387]])
# xyxy: tensor([[287.5254, 229.0192, 348.2635, 295.5726]])
# xyxyn: tensor([[0.4493, 0.4771, 0.5442, 0.6158]])
#
# 0: 480x640 1 red, 98.2ms
# Speed: 0.0ms preprocess, 98.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([1.])
# conf: tensor([0.8158])
# data: tensor([[284.4856, 227.2446, 344.3615, 291.3670,   3.0000,   0.8158,   1.0000]])
# id: tensor([3.])
# is_track: True
# orig_shape: (480, 640)
# shape: torch.Size([1, 7])
# xywh: tensor([[314.4235, 259.3058,  59.8759,  64.1224]])
# xywhn: tensor([[0.4913, 0.5402, 0.0936, 0.1336]])
# xyxy: tensor([[284.4856, 227.2446, 344.3615, 291.3670]])
# xyxyn: tensor([[0.4445, 0.4734, 0.5381, 0.6070]])
# Detected label: 1
# Speaking: 빨간불 탐지
#
# 0: 480x640 (no detections), 99.8ms
# Speed: 0.0ms preprocess, 99.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 112.2ms
# Speed: 2.7ms preprocess, 112.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 134.5ms
# Speed: 0.0ms preprocess, 134.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 114.8ms
# Speed: 5.0ms preprocess, 114.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 113.1ms
# Speed: 0.0ms preprocess, 113.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 107.0ms
# Speed: 0.0ms preprocess, 107.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 103.7ms
# Speed: 0.0ms preprocess, 103.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 114.4ms
# Speed: 0.0ms preprocess, 114.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
#
# 0: 480x640 (no detections), 175.3ms
# Speed: 0.0ms preprocess, 175.3ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([])
# conf: tensor([])
# data: tensor([], size=(0, 6))
# id: None
# is_track: False
# orig_shape: (480, 640)
# shape: torch.Size([0, 6])
# xywh: tensor([], size=(0, 4))
# xywhn: tensor([], size=(0, 4))
# xyxy: tensor([], size=(0, 4))
# xyxyn: tensor([], size=(0, 4))
