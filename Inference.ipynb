# %% [markdown]
# ## **Inference with Custom Model**

# %%
# %pip install openvino-dev
# %pip install pyttsx3 --upgrade

# %%
from ultralytics import YOLO

# Define the path to the model weights and the source directory of images
model_weights = 'runs/detect/train/weights/best.pt'
source_images = "C:/Users/wonha/OneDrive/Desktop/Wonha/UNIV/Personal_Projects/Pedestrain_Traffic_Light/Pedestrian Lights.v1i.yolov8/test/images"

# Create a YOLO object with the specified model weights and set the confidence threshold
yolo = YOLO(model_weights)

# Run detection on the source images
results = yolo.predict(source=source_images)

# %%
# %pip install opencv-python-headless
# %pip install lap
# %pip install pafy
# %pip install youtube-dl

# %%
import pyttsx3
engine = pyttsx3.init()
engine.say("테스트 메시지")
engine.runAndWait()

# %%
import cv2
from ultralytics import YOLO
import pyttsx3

# Load your trained model
model = YOLO('runs/detect/train/weights/best.pt')

# Initialize the text-to-speech engine
engine = pyttsx3.init()

# Open a handle to the default webcam
cap = cv2.VideoCapture(0)

def speak(text):
    print(f"Speaking: {text}")
    engine.say(text)
    engine.runAndWait()

# Ensure the webcam opened correctly
if not cap.isOpened():
    raise IOError("Cannot open webcam")

ret = True

while ret:
    ret, frame = cap.read()
    if not ret:
        print("Failed to grab frame")
        break

    # Perform detection
    results = model.track(frame, persist=True, conf=0.7)

    # Convert the result tensor to a list
    detections = results[0]

    # print(detections)

    # Display the frame with detections
    cv2.imshow('Real-time Traffic Light Detection', detections.plot())

    # Speak the traffic light color
    if detections.boxes.id is not None:    
        label = detections.names.values() # 수정된 부분
        print("Detected label:", label)  # Debugging line
        if label == 'green': # green
            speak("초록불 탐지")
        elif label == 'red': # red
            speak("빨간불 탐지")

    # Break the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the VideoCapture object and close all windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 115.3ms
# Speed: 2.5ms preprocess, 115.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 113.0ms
# Speed: 0.0ms preprocess, 113.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 105.7ms
# Speed: 1.0ms preprocess, 105.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 108.6ms
# Speed: 3.0ms preprocess, 108.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 105.1ms
# Speed: 2.0ms preprocess, 105.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 166.0ms
# Speed: 1.0ms preprocess, 166.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 113.5ms
# Speed: 1.0ms preprocess, 113.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 102.3ms
# Speed: 1.0ms preprocess, 102.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 106.6ms
# Speed: 1.0ms preprocess, 106.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 108.3ms
# Speed: 2.0ms preprocess, 108.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 161.0ms
# Speed: 1.5ms preprocess, 161.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 99.1ms
# Speed: 2.0ms preprocess, 99.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 99.7ms
# Speed: 1.0ms preprocess, 99.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 110.7ms
# Speed: 1.0ms preprocess, 110.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 108.7ms
# Speed: 3.2ms preprocess, 108.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 106.6ms
# Speed: 1.0ms preprocess, 106.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 151.4ms
# Speed: 2.0ms preprocess, 151.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 99.9ms
# Speed: 1.0ms preprocess, 99.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 104.2ms
# Speed: 1.0ms preprocess, 104.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 red, 104.4ms
# Speed: 1.0ms preprocess, 104.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected label: dict_values(['green', 'red'])
#
# 0: 480x640 1 red, 103.1ms
# Speed: 0.0ms preprocess, 103.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected label: dict_values(['green', 'red'])
#
# 0: 480x640 1 red, 104.2ms
# Speed: 1.0ms preprocess, 104.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected label: dict_values(['green', 'red'])
#
# 0: 480x640 1 red, 106.7ms
# Speed: 2.0ms preprocess, 106.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Detected label: dict_values(['green', 'red'])
#
# 0: 480x640 1 red, 100.8ms
# Speed: 1.0ms preprocess, 100.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected label: dict_values(['green', 'red'])
#
# 0: 480x640 1 red, 99.9ms
# Speed: 1.1ms preprocess, 99.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected label: dict_values(['green', 'red'])
#
# 0: 480x640 1 red, 101.9ms
# Speed: 2.0ms preprocess, 101.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected label: dict_values(['green', 'red'])
#
# 0: 480x640 1 red, 105.0ms
# Speed: 2.0ms preprocess, 105.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected label: dict_values(['green', 'red'])
#
# 0: 480x640 1 red, 130.5ms
# Speed: 1.4ms preprocess, 130.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected label: dict_values(['green', 'red'])
#
# 0: 480x640 1 red, 146.9ms
# Speed: 2.0ms preprocess, 146.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected label: dict_values(['green', 'red'])
#
# 0: 480x640 1 red, 147.6ms
# Speed: 1.5ms preprocess, 147.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected label: dict_values(['green', 'red'])
#
# 0: 480x640 1 red, 156.1ms
# Speed: 2.0ms preprocess, 156.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Detected label: dict_values(['green', 'red'])
#
# 0: 480x640 1 red, 152.1ms
# Speed: 2.9ms preprocess, 152.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected label: dict_values(['green', 'red'])
#
# 0: 480x640 1 red, 155.7ms
# Speed: 2.0ms preprocess, 155.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected label: dict_values(['green', 'red'])
#
# 0: 480x640 1 red, 146.3ms
# Speed: 3.3ms preprocess, 146.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected label: dict_values(['green', 'red'])
#
# 0: 480x640 1 red, 220.8ms
# Speed: 6.1ms preprocess, 220.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected label: dict_values(['green', 'red'])
#
# 0: 480x640 (no detections), 167.5ms
# Speed: 3.4ms preprocess, 167.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 182.8ms
# Speed: 3.5ms preprocess, 182.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 189.2ms
# Speed: 3.0ms preprocess, 189.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 281.1ms
# Speed: 4.9ms preprocess, 281.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 153.9ms
# Speed: 2.0ms preprocess, 153.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 153.2ms
# Speed: 2.0ms preprocess, 153.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 372.2ms
# Speed: 2.5ms preprocess, 372.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 153.9ms
# Speed: 3.1ms preprocess, 153.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 173.3ms
# Speed: 2.0ms preprocess, 173.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 148.9ms
# Speed: 3.0ms preprocess, 148.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 161.9ms
# Speed: 2.5ms preprocess, 161.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 148.2ms
# Speed: 2.0ms preprocess, 148.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 144.0ms
# Speed: 2.0ms preprocess, 144.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 145.3ms
# Speed: 2.0ms preprocess, 145.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 100.4ms
# Speed: 1.0ms preprocess, 100.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 109.2ms
# Speed: 1.0ms preprocess, 109.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 97.0ms
# Speed: 2.0ms preprocess, 97.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
