# %%
# %pip install roboflow
# %pip install torch torchvision
# %pip install ultralytics==8.0.196
# %pip install onnx

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196  Python-3.9.13 torch-1.8.1+cpu CPU (11th Gen Intel Core(TM) i5-1135G7 2.40GHz)
# Setup complete  (8 CPUs, 7.7 GB RAM, 158.7/219.9 GB disk)

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# c:\Users\wonha\OneDrive\Desktop\Wonha\UNIV\Personal_Projects\Pedestrain_Traffic_Light\Pedestrain_Traffic_Light_Detection

# %%
from roboflow import Roboflow

# %%
import torch
from pathlib import Path

# %%
from ultralytics import YOLO
from pathlib import Path

# Assuming your dataset is downloaded and extracted
# Update the path to your dataset if it's different
dataset_path = Path("C:/Users/wonha/OneDrive/Desktop/Wonha/UNIV/Personal_Projects/Pedestrain_Traffic_Light/blind_assist1.v2i.yolov8")  # Use the path where the dataset is extracted

# Load YOLOv8 pretrained model
model = YOLO("yolov8n.pt")  # Choose the appropriate model size

# Configure your custom dataset for training
# Make sure your dataset directory has 'images' and 'labels' subdirectories with training data
train_path = dataset_path / 'train'
val_path = dataset_path / 'valid'  # or 'val', depending on your dataset structure

# Set training parameters
train_params = {
    "data": "C:/Users/wonha/OneDrive/Desktop/Wonha/UNIV/Personal_Projects/Pedestrain_Traffic_Light/blind_assist1.v2i.yolov8/data.yaml",  # Path to your dataset configuration file
    "epochs": 5,  # Number of training epochs
}

# Start the training
model.train(**train_params)

# Evaluate model performance on the validation set
metrics = model.val()

# Optional: Export the model to ONNX format
path = model.export(format="onnx")
# Out:
# New https://pypi.org/project/ultralytics/8.1.9 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196  Python-3.9.13 torch-1.8.1+cpu CPU (11th Gen Intel Core(TM) i5-1135G7 2.40GHz)
# WARNING  Upgrade to torch>=2.0.0 for deterministic training.
# ...

# %%
import os

# Replace the path with your specific path
directory_path = os.path.expanduser('runs/detect/train4')

# List all files and directories in the specified path
contents = os.listdir(directory_path)
for item in contents:
    print(item)
# Out:
# args.yaml
# confusion_matrix.png
# confusion_matrix_normalized.png
# events.out.tfevents.1707123669.Wonha-Ryu.12884.1
# F1_curve.png
# labels.jpg
# labels_correlogram.jpg
# PR_curve.png
# P_curve.png
# results.csv
# results.png
# R_curve.png
# train_batch0.jpg
# train_batch1.jpg
# train_batch2.jpg
# val_batch0_labels.jpg
# val_batch0_pred.jpg
# val_batch1_labels.jpg
# val_batch1_pred.jpg
# val_batch2_labels.jpg
# val_batch2_pred.jpg
# weights

# %%
from IPython.display import display, Image

# %%
# %cd {HOME}
Image(filename=f'runs/detect/train4/confusion_matrix.png', width=600)
# Out:
# c:\Users\wonha\OneDrive\Desktop\Wonha\UNIV\Personal_Projects\Pedestrain_Traffic_Light\Pedestrain_Traffic_Light_Detection

# %%
# %cd {HOME}
Image(filename=f'runs/detect/train4/results.png', width=600)
# Out:
# c:\Users\wonha\OneDrive\Desktop\Wonha\UNIV\Personal_Projects\Pedestrain_Traffic_Light\Pedestrain_Traffic_Light_Detection

# %%
# %cd {HOME}
Image(filename=f'runs/detect/train4/val_batch0_pred.jpg', width=600)
# Out:
# c:\Users\wonha\OneDrive\Desktop\Wonha\UNIV\Personal_Projects\Pedestrain_Traffic_Light\Pedestrain_Traffic_Light_Detection
