# %%
# %pip install roboflow
# %pip install torch torchvision
# %pip install -U ultralytics
# %pip install onnx

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

# %%
import os
HOME = os.getcwd()
print(HOME)

# %%
from roboflow import Roboflow

# %%
import torch
from pathlib import Path

# %%
from ultralytics import YOLO
from pathlib import Path

# Assuming your dataset is downloaded and extracted
# Update the path to your dataset if it's different
dataset_path = Path("C:/Users/wonha/OneDrive/Desktop/Wonha/UNIV/Personal_Projects/Pedestrain_Traffic_Light/Pedestrian Lights.v1i.yolov8")  # Use the path where the dataset is extracted

# Load YOLOv8 pretrained model
model = YOLO("yolov8n.pt")  # Choose the appropriate model size

# Configure your custom dataset for training
# Make sure your dataset directory has 'images' and 'labels' subdirectories with training data
train_path = dataset_path / 'train'
val_path = dataset_path / 'valid'  # or 'val', depending on your dataset structure

# Set training parameters
train_params = {
    "data": "C:/Users/wonha/OneDrive/Desktop/Wonha/UNIV/Personal_Projects/Pedestrain_Traffic_Light/Pedestrian Lights.v1i.yolov8/data.yaml",  # Path to your dataset configuration file
    "epochs": 50,  # Number of training epochs
    "imgsz": 640,  # Depending on pedestrian traffic light size in your dataset
    "lr0": 0.001,  # Initial learning rate
    "lrf": 0.1,  # Final learning rate factor
    "weight_decay": 0.0005,  # L2 regularization
    "optimizer": "AdamW",  # Specifying optimizer
    "amp": True,  # Enable Automatic Mixed Precision
    "save_period": 5,  # Save model every 5 epochs
    "val": True,  # Enable validation
    "pretrained": True
}

# Start the training
model.train(**train_params)

# Evaluate model performance on the validation set
metrics = model.val()

# Optional: Export the model to ONNX format
path = model.export(format="onnx")

# %%
import os

# Replace the path with your specific path
directory_path = os.path.expanduser('runs/detect/train')

# List all files and directories in the specified path
contents = os.listdir(directory_path)
for item in contents:
    print(item)
# Out:
# args.yaml
# confusion_matrix.png
# confusion_matrix_normalized.png
# events.out.tfevents.1707920016.8f46126eeb4d.1871.0
# F1_curve.png
# labels.jpg
# labels_correlogram.jpg
# PR_curve.png
# P_curve.png
# results.csv
# results.png
# R_curve.png
# train_batch0.jpg
# train_batch1.jpg
# train_batch2.jpg
# train_batch2080.jpg
# train_batch2081.jpg
# train_batch2082.jpg
# val_batch0_labels.jpg
# val_batch0_pred.jpg
# val_batch1_labels.jpg
# val_batch1_pred.jpg
# val_batch2_labels.jpg
# val_batch2_pred.jpg
# weights

# %%
from IPython.display import display, Image

# %%
# %cd {HOME}
Image(filename=f'runs/detect/train/confusion_matrix.png', width=600)
# Out:
# [WinError 2] 지정된 파일을 찾을 수 없습니다: '{HOME}'
# c:\Users\wonha\OneDrive\Desktop\Wonha\UNIV\Personal_Projects\Pedestrain_Traffic_Light\Pedestrain_Traffic_Light_Detection

# %%
# %cd {HOME}
Image(filename=f'runs/detect/train/results.png', width=600)
# Out:
# [WinError 2] 지정된 파일을 찾을 수 없습니다: '{HOME}'
# c:\Users\wonha\OneDrive\Desktop\Wonha\UNIV\Personal_Projects\Pedestrain_Traffic_Light\Pedestrain_Traffic_Light_Detection

# %%
# %cd {HOME}
Image(filename=f'runs/detect/train/val_batch0_pred.jpg', width=600)
# Out:
# [WinError 2] 지정된 파일을 찾을 수 없습니다: '{HOME}'
# c:\Users\wonha\OneDrive\Desktop\Wonha\UNIV\Personal_Projects\Pedestrain_Traffic_Light\Pedestrain_Traffic_Light_Detection
